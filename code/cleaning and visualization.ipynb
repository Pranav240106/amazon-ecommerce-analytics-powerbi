# %%
import pandas as pd
import numpy as np

df = pd.read_excel("D:\Projects\Amazon Data Analysis\Amazon Cleaned Data.xlsx")
a = df.head()
print(a)
# Out:
#       OrderID  OrderDate  CustomerID   CustomerName ProductID  \
# 0  ORD0000001 2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1  ORD0000002 2023-12-30  CUST000178    Pooja Kumar    P00040
# 2  ORD0000003 2022-05-10  CUST047516    Sneha Singh    P00044
# 3  ORD0000004 2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4  ORD0000005 2023-02-04  CUST048677  Aditya Kapoor    P00029
#
#            ProductName        Category       Brand  Quantity  UnitPrice  \
# 0           Drone Mini           Books   BrightLux         3     106.59
# 1           Microphone  Home & Kitchen  UrbanStyle         1     251.37
# 2  Power Bank 20000mAh        Clothing  UrbanStyle         3      35.03
# 3       Webcam Full HD  Home & Kitchen      Zenith         5      33.58
# 4              T-Shirt        Clothing    KiddoFun         2     515.64
#
#    Discount    Tax  ShippingCost  TotalAmount     PaymentMethod OrderStatus  \
# 0      0.00   0.00          0.09       319.86        Debit Card   Delivered
# 1      0.05  19.10          1.74       259.64        Amazon Pay   Delivered
# 2      0.10   7.57          5.91       108.06        Debit Card   Delivered
# 3      0.15  11.42          5.53       159.66  Cash on Delivery   Delivered
# 4      0.25  38.67          9.23       821.36       Credit Card   Cancelled
#
#           City State        Country   SellerID
# 0   Washington    DC          India  SELL01967
# 1   Fort Worth    TX  United States  SELL01298
# 2       Austin    TX  United States  SELL00908
# 3    Charlotte    NC          India  SELL01164
# 4  San Antonio    TX         Canada  SELL01411

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderID        100000 non-null  object
#  1   OrderDate      100000 non-null  datetime64[ns]
#  2   CustomerID     100000 non-null  object
#  3   CustomerName   100000 non-null  object
#  4   ProductID      100000 non-null  object
#  5   ProductName    100000 non-null  object
#  6   Category       100000 non-null  object
#  7   Brand          100000 non-null  object
#  8   Quantity       100000 non-null  int64
#  9   UnitPrice      100000 non-null  float64
#  10  Discount       100000 non-null  float64
#  11  Tax            100000 non-null  float64
#  12  ShippingCost   100000 non-null  float64
#  13  TotalAmount    100000 non-null  float64
#  14  PaymentMethod  100000 non-null  object
#  15  OrderStatus    100000 non-null  object
#  16  City           100000 non-null  object
#  17  State          100000 non-null  object
#  18  Country        100000 non-null  object
#  19  SellerID       100000 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(13)
# memory usage: 15.3+ MB

# %%
df.describe()
# Out:
#                         OrderDate       Quantity      UnitPrice  \
# count                      100000  100000.000000  100000.000000
# mean   2022-06-30 23:55:49.440000       3.001400     302.905748
# min           2020-01-01 00:00:00       1.000000       5.000000
# 25%           2021-04-01 00:00:00       2.000000     154.190000
# 50%           2022-07-01 00:00:00       3.000000     303.070000
# 75%           2023-09-29 00:00:00       4.000000     451.500000
# max           2024-12-29 00:00:00       5.000000     599.990000
# std                           NaN       1.413548     171.840797
#
#             Discount            Tax   ShippingCost    TotalAmount
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.074226      68.468902       7.406660     918.256479
# min         0.000000       0.000000       0.000000       4.270000
# 25%         0.000000      15.920000       3.680000     340.890000
# 50%         0.050000      45.250000       7.300000     714.315000
# 75%         0.100000      96.060000      11.150000    1349.765000
# max         0.300000     538.460000      15.000000    3534.980000
# std         0.082583      74.131180       4.324057     724.508332

# %%
df.shape
# Out:
# (100000, 20)

# %%
df.dtypes
# Out:
# OrderID                  object
# OrderDate        datetime64[ns]
# CustomerID               object
# CustomerName             object
# ProductID                object
# ProductName              object
# Category                 object
# Brand                    object
# Quantity                  int64
# UnitPrice               float64
# Discount                float64
# Tax                     float64
# ShippingCost            float64
# TotalAmount             float64
# PaymentMethod            object
# OrderStatus              object
# City                     object
# State                    object
# Country                  object
# SellerID                 object
# dtype: object

# %%
df.columns
# Out:
# Index(['OrderID', 'OrderDate', 'CustomerID', 'CustomerName', 'ProductID',
#        'ProductName', 'Category', 'Brand', 'Quantity', 'UnitPrice', 'Discount',
#        'Tax', 'ShippingCost', 'TotalAmount', 'PaymentMethod', 'OrderStatus',
#        'City', 'State', 'Country', 'SellerID'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# OrderID          0
# OrderDate        0
# CustomerID       0
# CustomerName     0
# ProductID        0
# ProductName      0
# Category         0
# Brand            0
# Quantity         0
# UnitPrice        0
# Discount         0
# Tax              0
# ShippingCost     0
# TotalAmount      0
# PaymentMethod    0
# OrderStatus      0
# City             0
# State            0
# Country          0
# SellerID         0
# dtype: int64

# %%
# Number of duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt

numeric_cols = ['Quantity', 'UnitPrice', 'Discount',
                'Tax', 'ShippingCost', 'TotalAmount']

for col in numeric_cols:
    plt.figure(figsize=(6, 2))
    plt.boxplot(df[col], vert=False)
    plt.title(col)
    plt.show()

# %%
categorical_cols = [
    'Category',
    'Brand',
    'PaymentMethod',
    'OrderStatus',
    'Country'
]

for col in categorical_cols:
    print(f"\n{col}")
    print(df[col].value_counts())
# Out:
# Category
# Category
# Electronics          16853
# Sports & Outdoors    16804
# Books                16752
# Home & Kitchen       16610
# Toys & Games         16542
# Clothing             16439
# Name: count, dtype: int64
#
# Brand
# Brand
# ReadMore      10204
# FitLife       10147
# CoreTech      10127
# KiddoFun      10077
# Zenith         9990
# NexPro         9962
# Apex           9937
# BrightLux      9907
# UrbanStyle     9854
# HomeEase       9795
# Name: count, dtype: int64
#
# PaymentMethod
# PaymentMethod
# Credit Card         35038
# Debit Card          20024
# UPI                 15066
# Amazon Pay          15017
# Net Banking          9927
# Cash on Delivery     4928
# Name: count, dtype: int64
#
# OrderStatus
# OrderStatus
# Delivered    74628
# Shipped      15192
# Pending       4103
# Returned      3049
# Cancelled     3028
# Name: count, dtype: int64
#
# Country
# Country
# United States     70058
# India             15051
# Canada             5818
# United Kingdom     4943
# Australia          4130
# Name: count, dtype: int64

# %%
df[df['Quantity'] <= 0]
# Out:
# Empty DataFrame
# Columns: [OrderID, OrderDate, CustomerID, CustomerName, ProductID, ProductName, Category, Brand, Quantity, UnitPrice, Discount, Tax, ShippingCost, TotalAmount, PaymentMethod, OrderStatus, City, State, Country, SellerID]
# Index: []

# %%
df[df['UnitPrice'] <= 0]
# Out:
# Empty DataFrame
# Columns: [OrderID, OrderDate, CustomerID, CustomerName, ProductID, ProductName, Category, Brand, Quantity, UnitPrice, Discount, Tax, ShippingCost, TotalAmount, PaymentMethod, OrderStatus, City, State, Country, SellerID]
# Index: []

# %%
df[df['ShippingCost'] < 0]
# Out:
# Empty DataFrame
# Columns: [OrderID, OrderDate, CustomerID, CustomerName, ProductID, ProductName, Category, Brand, Quantity, UnitPrice, Discount, Tax, ShippingCost, TotalAmount, PaymentMethod, OrderStatus, City, State, Country, SellerID]
# Index: []

# %%
df[df['Tax'] < 0]
# Out:
# Empty DataFrame
# Columns: [OrderID, OrderDate, CustomerID, CustomerName, ProductID, ProductName, Category, Brand, Quantity, UnitPrice, Discount, Tax, ShippingCost, TotalAmount, PaymentMethod, OrderStatus, City, State, Country, SellerID]
# Index: []

# %%
df[df['TotalAmount'] < 0]
# Out:
# Empty DataFrame
# Columns: [OrderID, OrderDate, CustomerID, CustomerName, ProductID, ProductName, Category, Brand, Quantity, UnitPrice, Discount, Tax, ShippingCost, TotalAmount, PaymentMethod, OrderStatus, City, State, Country, SellerID]
# Index: []

# %%
df['Discount'].describe()
# Out:
# count    100000.000000
# mean          0.074226
# std           0.082583
# min           0.000000
# 25%           0.000000
# 50%           0.050000
# 75%           0.100000
# max           0.300000
# Name: Discount, dtype: float64

# %%
total_sales = df['TotalAmount'].sum()

total_orders = df['OrderID'].nunique()

total_customers = df['CustomerID'].nunique()

total_products_sold = df['Quantity'].sum()

average_order_value = df['TotalAmount'].mean()

average_discount = df['Discount'].mean() * 100

average_shipping = df['ShippingCost'].mean()

print(f"Total Sales: {total_sales:,.2f}")
print(f"Total Orders: {total_orders:,}")
print(f"Total Customers: {total_customers:,}")
print(f"Products Sold: {total_products_sold:,}")
print(f"Average Order Value: {average_order_value:.2f}")
print(f"Average Discount: {average_discount:.2f}%")
print(f"Average Shipping Cost: {average_shipping:.2f}")
# Out:
# Total Sales: 91,825,647.92
# Total Orders: 100,000
# Total Customers: 43,233
# Products Sold: 300,140
# Average Order Value: 918.26
# Average Discount: 7.42%
# Average Shipping Cost: 7.41

# %%
df['Year'] = df['OrderDate'].dt.year
df['Month'] = df['OrderDate'].dt.month_name()
df['Month_Number'] = df['OrderDate'].dt.month
df['Quarter'] = df['OrderDate'].dt.quarter

# %%
yearly_sales = df.groupby('Year')['TotalAmount'].sum().reset_index()

yearly_sales
# Out:
#    Year  TotalAmount
# 0  2020  18529864.02
# 1  2021  18248574.81
# 2  2022  18367248.41
# 3  2023  18513912.19
# 4  2024  18166048.49

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))

plt.plot(
    yearly_sales['Year'],
    yearly_sales['TotalAmount'],
    marker='o',
    linewidth=2
)

plt.title("Yearly Sales")
plt.xlabel("Year")
plt.ylabel("Sales")

plt.grid(True)

plt.show()

# %%
monthly_sales = (
    df.groupby(['Month_Number','Month'])['TotalAmount']
      .sum()
      .reset_index()
      .sort_values('Month_Number')
)

monthly_sales
# Out:
#     Month_Number      Month  TotalAmount
# 0              1    January   7883801.27
# 1              2   February   6931724.49
# 2              3      March   7766527.73
# 3              4      April   7646203.22
# 4              5        May   7864283.27
# 5              6       June   7654636.75
# 6              7       July   7737925.51
# 7              8     August   7890598.37
# 8              9  September   7558970.85
# 9             10    October   7654243.32
# 10            11   November   7495754.13
# 11            12   December   7740979.01

# %%
plt.figure(figsize=(12,5))

plt.bar(
    monthly_sales['Month'],
    monthly_sales['TotalAmount']
)

plt.xticks(rotation=45)

plt.title("Monthly Sales")

plt.xlabel("Month")

plt.ylabel("Sales")

plt.show()

# %%
category_sales = (
    df.groupby('Category')['TotalAmount']
      .sum()
      .sort_values(ascending=False)
      .reset_index()
)

category_sales
# Out:
#             Category  TotalAmount
# 0        Electronics  15584217.18
# 1  Sports & Outdoors  15345571.88
# 2              Books  15261837.01
# 3           Clothing  15253397.50
# 4       Toys & Games  15216684.99
# 5     Home & Kitchen  15163939.36

# %%
plt.figure(figsize=(10,5))

plt.bar(
    category_sales['Category'],
    category_sales['TotalAmount']
)

plt.xticks(rotation=45)

plt.title("Sales by Category")

plt.xlabel("Category")

plt.ylabel("Sales")

plt.show()

# %%
category_orders = (
    df.groupby('Category')['OrderID']
      .count()
      .sort_values(ascending=False)
      .reset_index()
)

category_orders
# Out:
#             Category  OrderID
# 0        Electronics    16853
# 1  Sports & Outdoors    16804
# 2              Books    16752
# 3     Home & Kitchen    16610
# 4       Toys & Games    16542
# 5           Clothing    16439

# %%
brand_sales = (
    df.groupby('Brand')['TotalAmount']
      .sum()
      .sort_values(ascending=False)
      .reset_index()
)

brand_sales
# Out:
#         Brand  TotalAmount
# 0    CoreTech   9343720.59
# 1    KiddoFun   9324749.55
# 2    ReadMore   9278406.63
# 3  UrbanStyle   9249027.45
# 4      Zenith   9239960.39
# 5        Apex   9147604.72
# 6      NexPro   9078824.97
# 7     FitLife   9061444.68
# 8   BrightLux   9056816.11
# 9    HomeEase   9045092.83

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))

plt.bar(brand_sales['Brand'], brand_sales['TotalAmount'])

plt.xticks(rotation=45)

plt.title("Sales by Brand")
plt.xlabel("Brand")
plt.ylabel("Total Sales")

plt.show()

# %%
top_products = (
    df.groupby('ProductName')['TotalAmount']
      .sum()
      .sort_values(ascending=False)
      .head(10)
      .reset_index()
)

top_products
# Out:
#            ProductName  TotalAmount
# 0    Memory Card 128GB   1935138.40
# 1        LED Desk Lamp   1921948.41
# 2  Mechanical Keyboard   1906963.54
# 3      Electric Kettle   1905751.79
# 4           Smartwatch   1901275.59
# 5          Dress Shirt   1896765.36
# 6         Water Bottle   1895467.95
# 7         Gaming Mouse   1895103.98
# 8         Kids Toy Car   1891082.43
# 9                Jeans   1882591.82

# %%
plt.figure(figsize=(12,6))

plt.barh(
    top_products['ProductName'],
    top_products['TotalAmount']
)

plt.title("Top 10 Products by Sales")
plt.xlabel("Sales")

plt.gca().invert_yaxis()

plt.show()

# %%
top_quantity = (
    df.groupby('ProductName')['Quantity']
      .sum()
      .sort_values(ascending=False)
      .head(10)
      .reset_index()
)

top_quantity
# Out:
#            ProductName  Quantity
# 0        LED Desk Lamp      6344
# 1         Water Bottle      6275
# 2    Memory Card 128GB      6240
# 3               Router      6202
# 4           Board Game      6200
# 5           Microphone      6196
# 6         Gaming Mouse      6170
# 7      Electric Kettle      6165
# 8  Mechanical Keyboard      6161
# 9       Vacuum Cleaner      6139

# %%
top_customers = (
    df.groupby('CustomerName')['TotalAmount']
      .sum()
      .sort_values(ascending=False)
      .head(10)
      .reset_index()
)

top_customers
# Out:
#    CustomerName  TotalAmount
# 0  Pooja Kapoor    547832.64
# 1  Vihaan Singh    526675.89
# 2   Pooja Singh    516451.45
# 3   Kabir Joshi    515361.68
# 4  Aditya Gupta    515005.09
# 5   Mohit Singh    513513.19
# 6  Sunita Mehta    511642.91
# 7    Aman Reddy    511236.91
# 8   Karan Singh    510900.60
# 9  Simran Singh    509337.35

# %%
plt.figure(figsize=(12,6))

plt.barh(
    top_customers['CustomerName'],
    top_customers['TotalAmount']
)

plt.title("Top 10 Customers by Spending")
plt.xlabel("Sales")

plt.gca().invert_yaxis()

plt.show()

# %%
customer_orders = (
    df.groupby('CustomerName')['OrderID']
      .count()
      .sort_values(ascending=False)
      .head(10)
      .reset_index()
)

customer_orders
# Out:
#    CustomerName  OrderID
# 0   Karan Joshi      556
# 1   Arjun Kumar      553
# 2  Pooja Kapoor      552
# 3   Rohit Gupta      547
# 4  Vihaan Singh      544
# 5  Aditya Mehta      543
# 6  Vihaan Mehta      541
# 7   Pooja Singh      538
# 8    Neha Kumar      538
# 9  Aditya Joshi      537

# %%
payment_method = (
    df.groupby('PaymentMethod')['TotalAmount']
      .sum()
      .sort_values(ascending=False)
      .reset_index()
)

payment_method
# Out:
#       PaymentMethod  TotalAmount
# 0       Credit Card  32122158.69
# 1        Debit Card  18538678.53
# 2               UPI  13896028.55
# 3        Amazon Pay  13697498.42
# 4       Net Banking   9055674.57
# 5  Cash on Delivery   4515609.16

# %%
plt.figure(figsize=(8,5))

plt.pie(
    payment_method['TotalAmount'],
    labels=payment_method['PaymentMethod'],
    autopct='%1.1f%%'
)

plt.title("Sales by Payment Method")

plt.show()

# %%
order_status = (
    df.groupby('OrderStatus')['OrderID']
      .count()
      .reset_index()
)

order_status
# Out:
#   OrderStatus  OrderID
# 0   Cancelled     3028
# 1   Delivered    74628
# 2     Pending     4103
# 3    Returned     3049
# 4     Shipped    15192

# %%
plt.figure(figsize=(7,5))

plt.bar(
    order_status['OrderStatus'],
    order_status['OrderID']
)

plt.title("Orders by Status")
plt.xlabel("Status")
plt.ylabel("Number of Orders")

plt.show()

# %%
country_sales = (
    df.groupby('Country')['TotalAmount']
      .sum()
      .sort_values(ascending=False)
      .reset_index()
)

country_sales
# Out:
#           Country  TotalAmount
# 0   United States  64310048.50
# 1           India  13875839.12
# 2          Canada   5323757.00
# 3  United Kingdom   4526896.86
# 4       Australia   3789106.44

# %%
state_sales = (
    df.groupby('State')['TotalAmount']
      .sum()
      .sort_values(ascending=False)
      .reset_index()
)

state_sales.head(10)
# Out:
#   State  TotalAmount
# 0    TX  22862540.54
# 1    CA  18231196.79
# 2    NC   4747701.73
# 3    WA   4660962.17
# 4    PA   4650673.88
# 5    CO   4638498.97
# 6    IL   4632847.44
# 7    OH   4615442.32
# 8    IN   4609048.43
# 9    FL   4597177.27

# %%
city_sales = (
    df.groupby('City')['TotalAmount']
      .sum()
      .sort_values(ascending=False)
      .reset_index()
)

city_sales.head(10)
# Out:
#            City  TotalAmount
# 0     Charlotte   4747701.73
# 1        Dallas   4730108.67
# 2      San Jose   4669614.33
# 3       Seattle   4660962.17
# 4  Philadelphia   4650673.88
# 5        Denver   4638498.97
# 6        Austin   4638403.18
# 7       Chicago   4632847.44
# 8   Los Angeles   4620629.78
# 9      Columbus   4615442.32

# %%
discount_category = (
    df.groupby('Category')['Discount']
      .mean()
      .sort_values(ascending=False)
      .reset_index()
)

discount_category
# Out:
#             Category  Discount
# 0     Home & Kitchen  0.075084
# 1        Electronics  0.074340
# 2       Toys & Games  0.074066
# 3  Sports & Outdoors  0.074000
# 4           Clothing  0.073970
# 5              Books  0.073896

# %%
discount_sales = (
    df.groupby('Discount')['TotalAmount']
      .sum()
      .reset_index()
)

discount_sales
# Out:
#    Discount  TotalAmount
# 0      0.00  39759304.30
# 1      0.05  18754249.73
# 2      0.10  13391000.91
# 3      0.15   8451571.63
# 4      0.20   6301022.17
# 5      0.25   3723201.49
# 6      0.30   1445297.69

# %%
numeric_df = df[['Quantity',
                 'UnitPrice',
                 'Discount',
                 'Tax',
                 'ShippingCost',
                 'TotalAmount']]

corr = numeric_df.corr()

corr
# Out:
#               Quantity  UnitPrice  Discount       Tax  ShippingCost  \
# Quantity      1.000000   0.004408 -0.000398  0.437884      0.020047
# UnitPrice     0.004408   1.000000  0.006159  0.526856      0.045773
# Discount     -0.000398   0.006159  1.000000 -0.077550      0.000315
# Tax           0.437884   0.526856 -0.077550  1.000000      0.023498
# ShippingCost  0.020047   0.045773  0.000315  0.023498      1.000000
# TotalAmount   0.594928   0.715808 -0.108088  0.779399      0.039349
#
#               TotalAmount
# Quantity         0.594928
# UnitPrice        0.715808
# Discount        -0.108088
# Tax              0.779399
# ShippingCost     0.039349
# TotalAmount      1.000000

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.imshow(corr, cmap='coolwarm')

plt.colorbar()

plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)

plt.yticks(range(len(corr.columns)), corr.columns)

plt.title("Correlation Matrix")

plt.show()
